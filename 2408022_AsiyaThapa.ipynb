# %% [markdown]
# 3 Tasks - To - Do:
# Please Solve all the Problems as instructed:
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:
# 1. Data Exploration and Understanding:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
import pandas as pd
worldHappiness = pd.read_csv("/content/drive/MyDrive/ConceptofAIandTechnology/Assignment/WHR-2024-5CS037.csv")

#to print first ten rows of dataset
print("First Ten rows of dataset: \n")
print(worldHappiness.head(10))

#identify the number of rows and columns
num_rows, num_columns = worldHappiness.shape
print("\nNumber of rows:")
print(num_rows)

print("\nNumber of columns:")
print(num_columns)

#list all columns and their datatypes
datatypes_column = worldHappiness.dtypes
print("\nData types:\n")
print(datatypes_column)
# Out:
# First Ten rows of dataset:
#
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
#mean, median and standard deviation for the score column
mean_score = worldHappiness['score'].mean()
median_score = worldHappiness['score'].median()
standard_deviation = worldHappiness['score'].std()

#print mean,median,standard deviation
print(f"Mean of score column: {mean_score:.2f}")
print(f"Median of score column: {median_score:.2f}")
print(f"Standard deviation of score column: {standard_deviation:.2f}")


#highest and lowest happiness score
highest_score = worldHappiness.loc[worldHappiness['score'].idxmax()]
lowest_score = worldHappiness.loc[worldHappiness['score'].idxmin()]

#print country with highest nd lowest score
print(f"\nCountry with the highest score: {highest_score['Country name']} ({highest_score['score']})")
print(f"Country with the lowest score: {lowest_score['Country name']} ({lowest_score['score']})")
# Out:
# Mean of score column: 5.53
# Median of score column: 5.79
# Standard deviation of score column: 1.17
#
# Country with the highest score: Finland (7.741)
# Country with the lowest score: Afghanistan (1.721)

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
#check missing values
missing_values = worldHappiness.isnull().sum()
print("Missing values in dataset:\n")
print(missing_values)
# Out:
# Missing values in dataset:
#
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
#filter dataset to show countries with score greater than 7.5
filtered_data = worldHappiness[worldHappiness['score']>7.5]
print("Countries with a score greater than 7.5:\n")
filtered_data
# Out:
# Countries with a score greater than 7.5:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#sort diletered dataset in descending order and display 10 rows
sorted_data = filtered_data.sort_values(by='Log GDP per capita', ascending= False)
print("\ Top 10 Countries with GDP per Capita with score greater than 7.5: \n")
sorted_data.head(10)
# Out:
# \ Top 10 Countries with GDP per Capita with score greater than 7.5:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
#create a new column happiness category
def happiness_Categorgy(score):
  if (score<4):
    return "Low"
  elif (4<=score<=6):
    return "Medium"
  else:
    return "High"

worldHappiness['Happiness Category'] = worldHappiness['score'].apply(happiness_Categorgy)

print("Countries based on happinesss score:\n")
worldHappiness[['Country name','score','Happiness Category']]
# Out:
# Countries based on happinesss score:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# 2. Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the data by Score (if not already sorted)
Top_10_happiest = worldHappiness.sort_values(by='score', ascending=False).head(10)

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score',hue='score',data=Top_10_happiest, palette='viridis')
plt.title('Top 10 Happiest Countries by Score', fontsize=16)
plt.xlabel('Country name', fontsize=12)
plt.ylabel('Happiness score', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiestCountry = worldHappiness.sort_values(by='score',ascending=True).head(10)
plt.figure(figsize=(10,6))
plt.plot(top_10_unhappiestCountry['Country name'],top_10_unhappiestCountry['score'],marker='o',color='red',linewidth=2)
plt.title('Top 10 Unhappiest Countries', fontsize=16)
plt.xlabel('Country Name', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.show()

# %% [markdown]
# Plot a histogram for the Score column to show its distribution and also interpret.

# %%
plt.figure(figsize=(10,6))
sns.histplot(worldHappiness['score'], bins=20, kde=True, color='pink')
plt.title('Distribution of Happiness Scores',fontsize=16)
plt.xlabel('Happiness score',fontsize=12)
plt.ylabel('Frequency',fontsize=12)

plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Log GDP per capita',y='score',hue='score',data=worldHappiness,palette='viridis',s=100)

plt.title("Relationship Between GDP per Capita and Happiness Score",fontsize=16)
plt.xlabel('GDP per Capita',fontsize=12)
plt.ylabel('Happiness Score',fontsize=12)

plt.show()

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
import pandas as pd


south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Step 2: Load the dataset (replace 'dataset.csv' with your actual file path)
data = pd.read_csv('/content/drive/MyDrive/ConceptofAIandTechnology/Assignment/WHR-2024-5CS037.csv')

# Step 3: Filter the dataset for South Asian countries
south_asia_data = data[data['Country name'].isin(south_asian_countries)]

# Step 4: Save the filtered dataframe as a separate CSV file
south_asia_data.to_csv('south_asia_dataset.csv', index=False)

print("South Asia dataset has been successfully created and saved as 'south_asia_dataset.csv'.")
# Out:
# South Asia dataset has been successfully created and saved as 'south_asia_dataset.csv'.

# %% [markdown]
# Task - 2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
south_asia_data['Composite Score'] = (
    0.40 * south_asia_data['Log GDP per capita'] +
    0.30 * south_asia_data['Social support'] +
    0.30 * south_asia_data['Healthy life expectancy']
)
print(south_asia_data[['Country name', 'Log GDP per capita',
                       'Social support', 'Healthy life expectancy',
                       'Composite Score']])

south_asia_data = south_asia_data.sort_values(by='Composite Score',ascending=False)

print("Ranked South Asian Countries based on Composite Score:\n")
print(south_asia_data[['Country name','Composite Score']])
# Out:
#     Country name  Log GDP per capita  Social support  Healthy life expectancy  \
# 92         Nepal               0.965           0.990                    0.443
# 107     Pakistan               1.069           0.600                    0.321
# 125        India               1.166           0.653                    0.417
# 127    Sri Lanka               1.361           1.179                    0.586
# 128   Bangladesh               1.122           0.249                    0.513
# 142  Afghanistan               0.628           0.000                    0.242
#
#      Composite Score
# 92            0.8159
# 107           0.7039
# 125           0.7874
# 127           1.0739
# 128           0.6774
# 142           0.3238
# Ranked South Asian Countries based on Composite Score:
#
#     Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
south_asia_data = south_asia_data.sort_values(by='Composite Score',ascending=False)

print("Ranked South Asian Countries based on Composite Score:\n")
print(south_asia_data[['Country name','Composite Score']])
# Out:
# Ranked South Asian Countries based on Composite Score:
#
#     Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Assuming 'south_asia_data' is a DataFrame containing the relevant data
top_5_countries = south_asia_data.head(5)

#Set the size of the plot
plt.figure(figsize=(10, 6))

#Create the horizontal bar plot using seaborn
sns.barplot(x=top_5_countries['Composite Score'], y=top_5_countries['Country name'],hue=top_5_countries['score'], palette='coolwarm')

#Set plot title and labels
plt.title('Top 5 South Asian Countries by Composite Score', fontsize=16)
plt.xlabel('Composite Score', fontsize=12)
plt.ylabel('Country', fontsize=12)

#Show the plot
plt.show()

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
#  Compare with original Score
# Create a scatter plot to compare
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Composite Score',y='score',data=south_asia_data,hue='Country name',s=100)
plt.title('Comparison of Composite Score and Original Score for South Asian Countries',fontsize=16)
plt.xlabel('Composite Score', fontsize=12)
plt.ylabel('Original Score', fontsize=12)

plt.show()

# %% [markdown]
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.

# %%
# Calculate Q1, Q3, and IQR for Score and GDP per Capita
Q1_score = south_asia_data['score'].quantile(0.25)
Q3_score = south_asia_data['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

Q1_gdp = south_asia_data['Log GDP per capita'].quantile(0.25)
Q3_gdp = south_asia_data['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

# Define outlier boundaries
outlier_score_lower = Q1_score - 1.5 * IQR_score
outlier_score_upper = Q3_score + 1.5 * IQR_score
outlier_gdp_lower = Q1_gdp - 1.5 * IQR_gdp
outlier_gdp_upper = Q3_gdp + 1.5 * IQR_gdp

# Identify outliers
outliers = south_asia_data[
    (south_asia_data['score'] < outlier_score_lower) |
    (south_asia_data['score'] > outlier_score_upper) |
    (south_asia_data['Log GDP per capita'] < outlier_gdp_lower) |
    (south_asia_data['Log GDP per capita'] > outlier_gdp_upper)
]
print("Outlier countries based on Score and GDP per Capita:\n")
print(outliers[['Country name', 'Log GDP per capita', 'score']])
# Out:
# Outlier countries based on Score and GDP per Capita:
#
#     Country name  Log GDP per capita  score
# 142  Afghanistan               0.628  1.721

# %% [markdown]
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a scatter plot
plt.figure(figsize=(10, 6))

# Plot non-outliers
sns.scatterplot( x='Log GDP per capita',y='score',
    data=south_asia_data[~south_asia_data.index.isin(outliers.index)],
    label='Non-Outliers',
    s=100
)

# Plot outliers
sns.scatterplot(
    x='Log GDP per capita',
    y='score',
    data=outliers,
    label='Outliers',
    color='red',
    s=100
)

plt.title('Scatter Plot of GDP per Capita vs. Score (Outliers Highlighted)', fontsize=16)
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Score', fontsize=12)

plt.show()

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
outliers_info = outliers[['Country name', 'Log GDP per capita', 'score']]

print("Outlier Countries and Their Characteristics:\n")
print(outliers_info)

# Explanation and discussion:
# These outliers can potentially skew the regional averages because their extreme values
# (either in terms of GDP or score) may not accurately represent the general trend for the region.
# Further investigation is needed to understand why these countries fall outside the typical range
# and whether they require any special handling in analysi
# Out:
# Outlier Countries and Their Characteristics:
#
#     Country name  Log GDP per capita  score
# 142  Afghanistan               0.628  1.721

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
# Calculate Pearson correlation between 'Freedom to Make Life Choices' and 'Generosity' with 'Score'
freedom_correlation = south_asia_data['Freedom to make life choices'].corr(south_asia_data['score'])
generosity_correlation = south_asia_data['Generosity'].corr(south_asia_data['score'])

print(f"Pearson Correlation between 'Freedom to Make Life Choices' and 'Score': {freedom_correlation}")
print(f"Pearson Correlation between 'Generosity' and 'Score': {generosity_correlation}")
# Out:
# Pearson Correlation between 'Freedom to Make Life Choices' and 'Score': 0.8005185224163315
# Pearson Correlation between 'Generosity' and 'Score': 0.874512371253192

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
# prompt: Create scatter plots with trendlines for these metrics against the Score.

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'south_asia_data' DataFrame is already loaded and processed

# Scatter plot for Freedom to Make Life Choices vs. Score
plt.figure(figsize=(10, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=south_asia_data,scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
plt.title('Freedom to Make Life Choices vs. Happiness Score (South Asia)')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Happiness Score')
plt.show()

# %%
# Scatter plot for Generosity vs. Score
plt.figure(figsize=(10, 6))
sns.regplot(x='Generosity', y='score', data=south_asia_data,scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
plt.title('Generosity vs. Happiness Score (South Asia)')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
# Discuss the strongest and weakest relationships based on correlation
if abs(freedom_correlation) > abs(generosity_correlation):
    print("The strongest relationship is between 'Freedom to Make Life Choices' and 'Score'.")
    print(f"Pearson Correlation: {freedom_correlation}")
    print("The scatter plot indicates a more pronounced trend with a stronger correlation.")
else:
    print("The strongest relationship is between 'Generosity' and 'Score'.")
    print(f"Pearson Correlation: {generosity_correlation}")
    print("The scatter plot indicates a more pronounced trend with a stronger correlation.")

# The weaker relationship would be the one with the smaller absolute correlation value.
if abs(freedom_correlation) < abs(generosity_correlation):
    print("The weakest relationship is between 'Freedom to Make Life Choices' and 'Score'.")
    print(f"Pearson Correlation: {freedom_correlation}")
else:
    print("The weakest relationship is between 'Generosity' and 'Score'.")
    print(f"Pearson Correlation: {generosity_correlation}")
# Out:
# The strongest relationship is between 'Generosity' and 'Score'.
# Pearson Correlation: 0.874512371253192
# The scatter plot indicates a more pronounced trend with a stronger correlation.
# The weakest relationship is between 'Freedom to Make Life Choices' and 'Score'.
# Pearson Correlation: 0.8005185224163315

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
# Add a new column 'GDP-Score Gap' which is the difference between GDP per Capita and Score
south_asia_data['GDP-Score Gap'] = south_asia_data['Log GDP per capita'] - south_asia_data['score']

# Show the updated dataframe with the new column
print(south_asia_data[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 127    Sri Lanka               1.361  3.898         -2.537
# 92         Nepal               0.965  5.158         -4.193
# 125        India               1.166  4.054         -2.888
# 107     Pakistan               1.069  4.657         -3.588
# 128   Bangladesh               1.122  3.886         -2.764
# 142  Afghanistan               0.628  1.721         -1.093

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# Rank the countries by 'GDP-Score Gap' in ascending order
ascending_gap = south_asia_data.sort_values(by='GDP-Score Gap', ascending=True)
print("Countries ranked by GDP-Score Gap (Ascending):\n")
print(ascending_gap[['Country name', 'GDP-Score Gap']])

# Rank the countries by 'GDP-Score Gap' in descending order
descending_gap = south_asia_data.sort_values(by='GDP-Score Gap', ascending=False)
print("\nCountries ranked by GDP-Score Gap (Descending):\n")
print(descending_gap[['Country name', 'GDP-Score Gap']])
# Out:
# Countries ranked by GDP-Score Gap (Ascending):
#
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888
# 128   Bangladesh         -2.764
# 127    Sri Lanka         -2.537
# 142  Afghanistan         -1.093
#
# Countries ranked by GDP-Score Gap (Descending):
#
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764
# 125        India         -2.888
# 107     Pakistan         -3.588
# 92         Nepal         -4.193

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
# Get the 3 most negative and 3 least negative values
top_positive_gap = descending_gap.head(3)
top_negative_gap = ascending_gap.head(3)

# Combine both groups for visualization
top_gaps = pd.concat([top_positive_gap, top_negative_gap])

# Create a new column to categorize the gaps as 'positive' and ' Negative'
top_gaps['Gap Type'] = top_gaps['GDP-Score Gap'].apply(lambda x: 'Positive' if x in top_positive_gap['GDP-Score Gap'].values else 'Negative')

# Plot a bar chart highlighting the top 3 most negative and least negative GDP-Score gaps with different colors
plt.figure(figsize=(10,6))
sns.barplot(x='GDP-Score Gap', y='Country name', data=top_gaps, hue='Gap Type', palette={'Positive': 'red', 'Negative': 'blue'})

plt.title('Top 3 Most Positive and  Negative GDP-Score Gaps', fontsize=16)
plt.xlabel('GDP-Score Gap', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# Print the countries with the largest positive and negative gaps for analysis
print("Top 3 Countries with the Largest Positive GDP-Score Gaps:\n")
print(most_negative_gap[['Country name', 'GDP-Score Gap']])

print("\nTop 3 Countries with the Largest Negative GDP-Score Gaps:\n")
print(least_negative_gap[['Country name', 'GDP-Score Gap']])

# Discussion:
# The countries with the largest positive GDP-Score gaps may have a higher GDP per Capita relative to their
# social or quality-of-life metrics (Score), indicating economic growth without corresponding improvement in
# societal welfare or life satisfaction.
# Conversely, countries with the largest negative GDP-Score gaps may have a lower GDP per Capita but higher
# scores, indicating better social support, health, or life satisfaction despite lower economic development.
# Such gaps could imply policy focus areas, where countries with positive gaps may need to invest more in
# social welfare, while those with negative gaps may need to prioritize economic growth to boost their overall well-being.
# Out:
# Top 3 Countries with the Largest Positive GDP-Score Gaps:
#
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764
#
# Top 3 Countries with the Largest Negative GDP-Score Gaps:
#
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
#   "United Arab Emirates", "Yemen"]
#
#   Complete the following task:

# %%
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon",
    "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
    "United Arab Emirates", "Yemen"
]

# Filter for Middle Eastern countries
middle_east_data = worldHappiness[worldHappiness['Country name'].isin(middle_east_countries)]

# Display the first few rows of the Middle Eastern dataset
print("Middle Eastern Countries Dataset:")
print(middle_east_data.head())
# Out:
# Middle Eastern Countries Dataset:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
# 27          Saudi Arabia  6.594               1.842           1.361
# 61               Bahrain  5.959                 NaN             NaN
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
# 27                    0.511                         0.787       0.114
# 61                      NaN                           NaN         NaN
#
#     Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %% [markdown]
# Complete the following task:
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
# Calculate mean and standard deviation of 'score' for South Asia
south_asia_mean_score = south_asia_data['score'].mean()
south_asia_std_score = south_asia_data['score'].std()

print(f"South Asia: Mean Score = {south_asia_mean_score:.2f}, Standard Deviation = {south_asia_std_score:.2f}")

# Calculate mean and standard deviation of 'score' for the Middle East
middle_east_mean_score = middle_east_data['score'].mean()
middle_east_std_score = middle_east_data['score'].std()

print(f"Middle East: Mean Score = {middle_east_mean_score:.2f}")
print(f"Standard Deviation = {middle_east_std_score:.2f}")

# Compare average happiness scores
if south_asia_mean_score > middle_east_mean_score:
    print("South Asia has a higher average happiness score.")
elif middle_east_mean_score > south_asia_mean_score:
    print("The Middle East has a higher average happiness score.")
else:
    print("Both regions have the same average happiness score.")
# Out:
# South Asia: Mean Score = 3.90, Standard Deviation = 1.18
# Middle East: Mean Score = 5.41
# Standard Deviation = 1.57
# The Middle East has a higher average happiness score.

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
# Top and bottom 3 countries in South Asia
top3_south_asia = south_asia_data.nlargest(3, 'score')
bottom3_south_asia = south_asia_data.nsmallest(3, 'score')
print("Top 3 Countries in South Asia:")
print(top3_south_asia[['Country name', 'score']])

print("\nBottom 3 Countries in South Asia:")
print(bottom3_south_asia[['Country name', 'score']])

# Top and bottom 3 countries in the Middle East
top3_middle_east = middle_east_data.nlargest(3, 'score')
bottom3_middle_east = middle_east_data.nsmallest(3, 'score')
print("\nTop 3 Countries in the Middle East:")
print(top3_middle_east[['Country name', 'score']])

print("\nBottom 3 Countries in the Middle East:")
print(bottom3_middle_east[['Country name', 'score']])
# Out:
# Top 3 Countries in South Asia:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
#
# Bottom 3 Countries in South Asia:
#     Country name  score
# 142  Afghanistan  1.721
# 128   Bangladesh  3.886
# 127    Sri Lanka  3.898
#
# Top 3 Countries in the Middle East:
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
#
# Bottom 3 Countries in the Middle East:
#     Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %%
# Plotting bar charts for comparison

plt.figure(figsize=(12, 6))

# South Asia
plt.subplot(1, 2, 1)
sns.barplot(x='Country name', y='score', data=pd.concat([top3_south_asia, bottom3_south_asia]), palette='viridis',hue='score')
plt.title('Top/Bottom 3 South Asian Countries by Score')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability

# Middle East
plt.subplot(1, 2, 2)
sns.barplot(x='Country name', y='score', data=pd.concat([top3_middle_east, bottom3_middle_east]), palette='magma',hue='score')
plt.title('Top/Bottom 3 Middle Eastern Countries by Score')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
#
#   • Which metrics show the largest disparity between the two regions?

# %%
# Calculate mean values for South Asia
south_asia_metrics = south_asia_data[['Log GDP per capita', 'Social support', 'Healthy life expectancy']].mean()

# Calculate mean values for the Middle East
middle_east_metrics = middle_east_data[['Log GDP per capita', 'Social support', 'Healthy life expectancy']].mean()

# Combine the metrics into a DataFrame for visualization
metrics_comparison = pd.DataFrame({
    'Metric': ['GDP per Capita', 'Social Support', 'Healthy Life Expectancy'],
    'South Asia': south_asia_metrics.values,
    'Middle East': middle_east_metrics.values
})

print("Metrics Comparison Table:")
print(metrics_comparison)

# Plotting grouped bar chart
metrics_comparison.set_index('Metric').plot(kind='bar', figsize=(10, 6), color=['skyblue', 'orange'])
plt.title('Metric Comparisons: South Asia vs Middle East')
plt.ylabel('Average Value')
plt.xticks(rotation=0)
plt.legend(title='Region')

plt.show()
# Out:
# Metrics Comparison Table:
#                     Metric  South Asia  Middle East
# 0           GDP per Capita    1.051833     1.496333
# 1           Social Support    0.611833     1.152778
# 2  Healthy Life Expectancy    0.420333     0.554111

# %%
disparities = (middle_east_metrics - south_asia_metrics).abs()

# Find the largest disparity
largest_disparity_metric = disparities.idxmax()
largest_disparity_value = disparities.max()

print("\nMetric Disparities:")
print(disparities)

print(f"\nThe largest disparity is in '{largest_disparity_metric}' with a difference of {largest_disparity_value:.2f}.")
# Out:
# Metric Disparities:
# Log GDP per capita         0.444500
# Social support             0.540944
# Healthy life expectancy    0.133778
# dtype: float64
#
# The largest disparity is in 'Social support' with a difference of 0.54.

# %% [markdown]
# 4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
# Calculate range and CV for South Asia
south_asia_range = south_asia_data['score'].max() - south_asia_data['score'].min()

south_asia_cv = south_asia_data['score'].std() / south_asia_data['score'].mean()

# Calculate range and CV for the Middle East
middle_east_range = middle_east_data['score'].max() - middle_east_data['score'].min()

middle_east_cv = middle_east_data['score'].std() / middle_east_data['score'].mean()

# Display results
print("Happiness Disparity Analysis:")
print(f"South Asia: Range = {south_asia_range:.2f}, CV = {south_asia_cv:.2f}%")
print(f"Middle East: Range = {middle_east_range:.2f}, CV = {middle_east_cv:.2f}%")

# Determine which region has greater variability
if south_asia_cv > middle_east_cv:
    print("South Asia has greater variability in happiness.")
else:
    print("The Middle East has greater variability in happiness.")
# Out:
# Happiness Disparity Analysis:
# South Asia: Range = 3.44, CV = 0.30%
# Middle East: Range = 4.63, CV = 0.29%
# South Asia has greater variability in happiness.

# %% [markdown]
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
# Correlation analysis for South Asia
print("Correlation Analysis for South Asia:")
freedom_score_corr_sa = south_asia_data['Freedom to make life choices'].corr(south_asia_data['score'])
generosity_score_corr_sa = south_asia_data['Generosity'].corr(south_asia_data['score'])

print(f"Freedom to make life choices vs. Score: {freedom_score_corr_sa:.2f}")
print(f"Generosity vs. Score: {generosity_score_corr_sa:.2f}")

# Scatter plots for South Asia
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Freedom to make life choices', y='score', data=south_asia_data)
plt.title('South Asia: Freedom vs. Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Generosity', y='score', data=south_asia_data)
plt.title('South Asia: Generosity vs. Score')

plt.tight_layout()
plt.show()

# Correlation analysis for the Middle East
print("\nCorrelation Analysis for the Middle East:")
freedom_score_corr_me = middle_east_data['Freedom to make life choices'].corr(middle_east_data['score'])
generosity_score_corr_me = middle_east_data['Generosity'].corr(middle_east_data['score'])

print(f"Freedom to make life choices vs. Score: {freedom_score_corr_me:.2f}")
print(f"Generosity vs. Score: {generosity_score_corr_me:.2f}")


# Scatter plots for the Middle East
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Freedom to make life choices', y='score', data=middle_east_data)
plt.title('Middle East: Freedom vs. Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Generosity', y='score', data=middle_east_data)
plt.title('Middle East: Generosity vs. Score')

plt.tight_layout()
plt.show()
# Out:
# Correlation Analysis for South Asia:
# Freedom to make life choices vs. Score: 0.80
# Generosity vs. Score: 0.87
# Correlation Analysis for the Middle East:
# Freedom to make life choices vs. Score: 0.86
# Generosity vs. Score: 0.63

# %% [markdown]
# • Create scatter plots to visualize and interpret the relationships.

# %% [markdown]
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
def detect_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

# Detect outliers for South Asia - Score and GDP per Capita
south_asia_outliers_score, south_asia_lower_score, south_asia_upper_score = detect_outliers(south_asia_data, 'score')
south_asia_outliers_gdp, south_asia_lower_gdp, south_asia_upper_gdp = detect_outliers(south_asia_data, 'Log GDP per capita')

# Detect outliers for the Middle East - Score and GDP per Capita
middle_east_outliers_score, middle_east_lower_score, middle_east_upper_score = detect_outliers(middle_east_data, 'score')
middle_east_outliers_gdp, middle_east_lower_gdp, middle_east_upper_gdp = detect_outliers(middle_east_data, 'Log GDP per capita')

# Display outliers
print("South Asia - Outliers based on Score:")
print(south_asia_outliers_score[['Country name', 'score']])

print("\nSouth Asia - Outliers based on GDP per Capita:")
print(south_asia_outliers_gdp[['Country name', 'Log GDP per capita']])

print("\nMiddle East - Outliers based on Score:")
print(middle_east_outliers_score[['Country name', 'score']])

print("\nMiddle East - Outliers based on GDP per Capita:")
print(middle_east_outliers_gdp[['Country name', 'Log GDP per capita']])
# Out:
# South Asia - Outliers based on Score:
#     Country name  score
# 142  Afghanistan  1.721
#
# South Asia - Outliers based on GDP per Capita:
#     Country name  Log GDP per capita
# 142  Afghanistan               0.628
#
# Middle East - Outliers based on Score:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Middle East - Outliers based on GDP per Capita:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []

# %%
plt.figure(figsize=(14, 6))

# South Asia - Score vs GDP per Capita
plt.subplot(1, 2, 1)
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_data, label='Normal', color='blue')
sns.scatterplot(x=south_asia_outliers_score['Log GDP per capita'], y=south_asia_outliers_score['score'], color='red', label='Outliers')
plt.title('South Asia: Outliers based on Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')

# Middle East - Score vs GDP per Capita
plt.subplot(1, 2, 2)
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_data, label='Normal', color='green')
sns.scatterplot(x=middle_east_outliers_score['Log GDP per capita'], y=middle_east_outliers_score['score'], color='red', label='Outliers')
plt.title('Middle East: Outliers based on Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
#   • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Create a combined DataFrame with region labels for easier comparison
south_asia_data['Region'] = 'South Asia'
middle_east_data['Region'] = 'Middle East'

# Combine the data from both regions
combined_data = pd.concat([south_asia_data[['score', 'Region']], middle_east_data[['score', 'Region']]])

# Create the boxplot comparing the distribution of Score between South Asia and the Middle East
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=combined_data, palette='Set2')
plt.title('Comparison of Happiness Score Distribution between South Asia and the Middle East')
plt.xlabel('Region')
plt.ylabel('Happiness Score')
plt.show()
# Out:
# <ipython-input-65-4f129ce27294>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   middle_east_data['Region'] = 'Middle East'
# <ipython-input-65-4f129ce27294>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='score', data=combined_data, palette='Set2')

# %%
#Distribution: The Middle East has a wider range of happiness scores, while South Asia's scores are more closely grouped together.
#Medians: The Middle East’s happiness scores are higher (around 5.5-6.0), while South Asia's are lower (around 4.0-4.5).
#Outliers:
#South Asia: There is one score much lower than the rest (below 2.0).
#Middle East: There is no extreme scores, but the range is bigger (2.8-7.2).
#Countries in the Middle East tend to have higher happiness scores with more differences, while South Asia has lower scores with one big exception
